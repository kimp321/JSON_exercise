# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('xAPI-Edu-Data.csv')
df.head(50)
# Out:
#    gender  NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       M           KW       KuwaIT    lowerlevel    G-04         A       IT
# 1       M           KW       KuwaIT    lowerlevel    G-04         A       IT
# 2       M           KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M           KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M           KW       KuwaIT    lowerlevel    G-04         A       IT
# 5       F           KW       KuwaIT    lowerlevel    G-04         A       IT
# 6       M           KW       KuwaIT  MiddleSchool    G-07         A     Math
# 7       M           KW       KuwaIT  MiddleSchool    G-07         A     Math
# 8       F           KW       KuwaIT  MiddleSchool    G-07         A     Math
# 9       F           KW       KuwaIT  MiddleSchool    G-07         B       IT
# 10      M           KW       KuwaIT  MiddleSchool    G-07         A     Math
# 11      M           KW       KuwaIT  MiddleSchool    G-07         B     Math
# 12      M           KW       KuwaIT    lowerlevel    G-04         A       IT
# 13      M      lebanon      lebanon  MiddleSchool    G-08         A     Math
# 14      F           KW       KuwaIT  MiddleSchool    G-08         A     Math
# 15      F           KW       KuwaIT  MiddleSchool    G-06         A       IT
# 16      M           KW       KuwaIT  MiddleSchool    G-07         B       IT
# 17      M           KW       KuwaIT  MiddleSchool    G-07         A     Math
# 18      F           KW       KuwaIT  MiddleSchool    G-07         A       IT
# 19      M           KW       KuwaIT  MiddleSchool    G-07         B       IT
# 20      F           KW       KuwaIT  MiddleSchool    G-07         A       IT
# 21      F           KW       KuwaIT  MiddleSchool    G-07         B       IT
# 22      M           KW       KuwaIT  MiddleSchool    G-07         A       IT
# 23      M           KW       KuwaIT  MiddleSchool    G-07         A       IT
# 24      M           KW       KuwaIT  MiddleSchool    G-07         B       IT
# 25      M           KW       KuwaIT  MiddleSchool    G-07         A       IT
# 26      M           KW       KuwaIT  MiddleSchool    G-07         B       IT
# 27      M           KW       KuwaIT  MiddleSchool    G-08         A   Arabic
# 28      M           KW       KuwaIT  MiddleSchool    G-08         A  Science
# 29      F           KW       KuwaIT  MiddleSchool    G-08         A   Arabic
# 30      F           KW       KuwaIT  MiddleSchool    G-08         A   Arabic
# 31      M           KW       KuwaIT  MiddleSchool    G-07         A       IT
# 32      F           KW       KuwaIT    lowerlevel    G-07         A       IT
# 33      M           KW       KuwaIT    lowerlevel    G-05         A  English
# 34      M           KW       KuwaIT  MiddleSchool    G-07         B  Science
# 35      M           KW       KuwaIT  MiddleSchool    G-07         A  English
# 36      M           KW       KuwaIT  MiddleSchool    G-07         B  Science
# 37      F        Egypt        Egypt  MiddleSchool    G-07         A       IT
# 38      M           KW       KuwaIT  MiddleSchool    G-06         A       IT
# 39      F  SaudiArabia  SaudiArabia  MiddleSchool    G-07         B  Science
# 40      F           KW       KuwaIT  MiddleSchool    G-07         A       IT
# 41      M           KW       KuwaIT  MiddleSchool    G-07         A       IT
# 42      M           KW       KuwaIT    HighSchool    G-09         A       IT
# 43      F           KW       KuwaIT    HighSchool    G-09         A       IT
# 44      F           KW       KuwaIT    HighSchool    G-09         A       IT
# 45      M           KW       KuwaIT  MiddleSchool    G-07         A    Quran
# 46      M           KW       KuwaIT    lowerlevel    G-05         A  English
# 47      F           KW       KuwaIT    HighSchool    G-12         A  English
# 48      F           KW       KuwaIT    HighSchool    G-12         A  English
# 49      F           KW       KuwaIT    HighSchool    G-12         A  English
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0         F   Father           15                16                  2
# 1         F   Father           20                20                  3
# 2         F   Father           10                 7                  0
# 3         F   Father           30                25                  5
# 4         F   Father           40                50                 12
# 5         F   Father           42                30                 13
# 6         F   Father           35                12                  0
# 7         F   Father           50                10                 15
# 8         F   Father           12                21                 16
# 9         F   Father           70                80                 25
# 10        F   Father           50                88                 30
# 11        F   Father           19                 6                 19
# 12        F   Father            5                 1                  0
# 13        F   Father           20                14                 12
# 14        F      Mum           62                70                 44
# 15        F   Father           30                40                 22
# 16        F   Father           36                30                 20
# 17        F   Father           55                13                 35
# 18        F      Mum           69                15                 36
# 19        F      Mum           70                50                 40
# 20        F   Father           60                60                 33
# 21        F   Father           10                12                  4
# 22        F   Father           15                21                  2
# 23        F   Father            2                 0                  2
# 24        F   Father            0                 2                  3
# 25        F   Father            8                 7                 30
# 26        F   Father           19                19                 25
# 27        F   Father           25                15                 12
# 28        F   Father           75                85                 52
# 29        F   Father           30                90                 33
# 30        F   Father           35                80                 50
# 31        F   Father            4                 5                 40
# 32        F   Father            2                19                 10
# 33        F   Father            8                22                  9
# 34        F   Father           12                11                  8
# 35        F   Father           10                12                 17
# 36        F      Mum            8                 6                  4
# 37        F   Father           45                54                 26
# 38        F   Father            0                 0                  0
# 39        F   Father           50                90                 37
# 40        F   Father           14                13                  3
# 41        F   Father           19                20                 16
# 42        F   Father           10                12                  7
# 43        F   Father           30                35                 28
# 44        F   Father           33                33                 30
# 45        F   Father           20                12                 15
# 46        F   Father            7                10                  1
# 47        F      Mum           70                 4                 39
# 48        F      Mum           13                80                 40
# 49        F   Father           29                39                 50
#
#     Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0           20                   Yes                     Good
# 1           25                   Yes                     Good
# 2           30                    No                      Bad
# 3           35                    No                      Bad
# 4           50                    No                      Bad
# 5           70                   Yes                      Bad
# 6           17                    No                      Bad
# 7           22                   Yes                     Good
# 8           50                   Yes                     Good
# 9           70                   Yes                     Good
# 10          80                   Yes                     Good
# 11          12                   Yes                     Good
# 12          11                    No                      Bad
# 13          19                    No                      Bad
# 14          60                    No                      Bad
# 15          66                   Yes                     Good
# 16          80                    No                      Bad
# 17          90                    No                      Bad
# 18          96                   Yes                     Good
# 19          99                   Yes                     Good
# 20          90                    No                      Bad
# 21          80                    No                      Bad
# 22          90                    No                      Bad
# 23          50                    No                      Bad
# 24          70                   Yes                     Good
# 25          40                   Yes                     Good
# 26          40                   Yes                      Bad
# 27          33                    No                      Bad
# 28          43                   Yes                     Good
# 29          35                    No                      Bad
# 30          70                   Yes                     Good
# 31          16                   Yes                     Good
# 32          50                   Yes                     Good
# 33          40                    No                      Bad
# 34          40                    No                      Bad
# 35          30                    No                      Bad
# 36          22                   Yes                     Good
# 37          90                   Yes                     Good
# 38           4                    No                      Bad
# 39          70                   Yes                     Good
# 40          70                    No                      Bad
# 41          50                    No                     Good
# 42          33                   Yes                     Good
# 43          90                   Yes                     Good
# 44          90                    No                      Bad
# 45          70                    No                     Good
# 46          30                    No                      Bad
# 47          90                   Yes                     Good
# 48          88                   Yes                     Good
# 49          77                   Yes                     Good
#
#    StudentAbsenceDays Class
# 0             Under-7     M
# 1             Under-7     M
# 2             Above-7     L
# 3             Above-7     L
# 4             Above-7     M
# 5             Above-7     M
# 6             Above-7     L
# 7             Under-7     M
# 8             Under-7     M
# 9             Under-7     M
# 10            Under-7     H
# 11            Under-7     M
# 12            Above-7     L
# 13            Above-7     L
# 14            Above-7     H
# 15            Under-7     M
# 16            Above-7     M
# 17            Above-7     M
# 18            Under-7     M
# 19            Under-7     H
# 20            Above-7     M
# 21            Under-7     M
# 22            Under-7     M
# 23            Above-7     L
# 24            Above-7     L
# 25            Above-7     L
# 26            Under-7     M
# 27            Above-7     L
# 28            Under-7     M
# 29            Under-7     M
# 30            Under-7     H
# 31            Above-7     L
# 32            Above-7     L
# 33            Above-7     L
# 34            Above-7     L
# 35            Above-7     L
# 36            Above-7     L
# 37            Under-7     M
# 38            Above-7     L
# 39            Under-7     M
# 40            Above-7     L
# 41            Under-7     M
# 42            Above-7     L
# 43            Under-7     M
# 44            Under-7     M
# 45            Above-7     L
# 46            Above-7     L
# 47            Under-7     H
# 48            Under-7     H
# 49            Under-7     M

# %%
len(df)
# Out:
# 480

# %%
http://pandas.pydata.org/pandas-docs/version/0.15.0/visualization.html

# %%
df.plot()
plt.show()

# %%
df.hist()
plt.show()

# %%
df.boxplot() 
plt.show()

# %%
female = df[df['gender']=='F']
len(female)
# Out:
# 175

# %%
male = df[df['gender']=='M']
len(male)
# Out:
# 305

# %%
raisedhands_female = female['raisedhands']
raisedhands_female.head()
# Out:
# 5     42
# 8     12
# 9     70
# 14    62
# 15    30
# Name: raisedhands, dtype: int64

# %%
np.mean(raisedhands_female)
# Out:
# 52.862857142857145

# %%
female_std = np.std(raisedhands_female)
female_std
# Out:
# 30.13158841495356
